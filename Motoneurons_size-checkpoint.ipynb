# %%
19 Jan - 

    
151 neurons in total with 30 AAvs and 121 CTBs

M162 = 6 AAvs   in 53 images
M163 = 2 Aavs   in 64 images
M164 = 17 AAvs  in 31 images
M205 = 5 Aavs   in 8  images
# Out:
#   File "<ipython-input-1-c834098a0637>", line 1
#     19 Jan -
#        ^
# SyntaxError: invalid syntax

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Sample data
data1 = pd.Series([305.949,510.943,989.386,782.368,286.2,284.881,271.687,203.27,340.492,229.335,413.088,298.916,790.33,246.827,282.07,367.204,480.385,555.738,258.417,618.598,867.881,595.893,204.691,205.036,838.196,566.38,412.989,225.97,355.98,281.459])
data2 = pd.Series([145.102,364.404,629.29,566.42,392.01,728.862,640.62,801.732,667.36,605.284,742.977,429.783,324.536,969.563,391.36,574.774,453.524,432.245,462.052,702.091,288.838,154.75,146.837,430.838,451.501,467.416,300.62,987.395,323.775,510.931,513.401,196.075,662.436,318.293,622.087,502.645,537.91,295.257,450.093,396.052,444.242,378.712,616.258,527.389,695.502,625.017,750.563,749.099,536.695,653.883,905.191,680.897,685.636,899.289,733.028,288.489,616.573,393.355,790.761,579.693,466.124,845.003,641.777,690.462,848.191,510.199,544.364,672.496,429.718,393.312,384.954,336.7,581.976,588.439,458.627,449.407,757.715,729.409,631.092,432.648,864.477,583.054,573.274,375.174,653.323,617.564,845.176,253.204,561.038,765.126,585.552,844.271,581.33,797.223,648.627,659.355,710.194,618.468,498.351,729.022,571.292,561.167,555.566,491.242,474.095,856.076,952.024,554.791,481.634,747.289,246.87,289.911,618.727,386.419,448.201,668.489,536.997,516.704,690.836,768.575,762.92])

# Plotting the histograms
plt.hist(data1, bins=12, alpha=0.5, label='Population 1', color='b')
plt.hist(data2, bins=12, alpha=0.5, label='Population 2', color='r')
plt.axvline(data1.median(), color='b', linestyle='dashed', linewidth=2)
plt.axvline(data2.median(), color='r', linestyle='dashed', linewidth=2)





# Adding a legend
plt.legend()

# # Display the plot
# plt.show()
plt.savefig('out_6mm.svg', format='svg', dpi=1200)

# %%
print(data2.median())
# Out:
# 573.274

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Sample data
data2 = pd.Series([145.102,364.404,629.29,566.42,392.01,728.862,640.62,801.732,667.36,605.284,742.977,429.783,324.536,969.563,391.36,574.774,453.524,432.245,462.052,702.091,288.838,154.75,146.837,430.838,451.501,467.416,300.62,987.395,323.775,510.931,513.401,196.075,662.436,318.293,622.087,502.645,537.91,295.257,450.093,396.052,444.242,378.712,616.258,527.389,695.502,625.017,750.563,749.099,536.695,653.883,905.191,680.897,685.636,899.289,733.028,288.489,616.573,393.355,790.761,579.693,466.124,845.003,641.777,690.462,848.191,510.199,544.364,672.496,429.718,393.312,384.954,336.7,581.976,588.439,458.627,449.407,757.715,729.409,631.092,432.648,864.477,583.054,573.274,375.174,653.323,617.564,845.176,253.204,561.038,765.126,585.552,844.271,581.33,797.223,648.627,659.355,710.194,618.468,498.351,729.022,571.292,561.167,555.566,491.242,474.095,856.076,952.024,554.791,481.634,747.289,246.87,289.911,618.727,386.419,448.201,668.489,536.997,516.704,690.836,768.575,762.92])

# Plotting the histograms
plt.hist(data2, bins=10, alpha=0.5, label='Population 2', color='r')
plt.axvline(data2.mean(), color='r', linestyle='dashed', linewidth=2)

# Adding a legend
plt.legend()

# Display the plot
plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Sample data
data1 = pd.Series([305.949,510.943,989.386,782.368,286.2,284.881,271.687,203.27,340.492,229.335,413.088,298.916,790.33,246.827,282.07,367.204,480.385,555.738,258.417,618.598,867.881,595.893,204.691,205.036,838.196,566.38,412.989,225.97,355.98,281.459])

# Plotting the histograms
plt.hist(data1, bins=10, alpha=0.5, label='Population 1', color='b')
plt.axvline(data1.mean(), color='b', linestyle='dashed', linewidth=2)

# Adding a legend
plt.legend()

# Display the plot
plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy.stats import norm

# Sample data
data2 = pd.Series([145.102,364.404,629.29,566.42,392.01,728.862,640.62,801.732,667.36,605.284,742.977,429.783,324.536,969.563,391.36,574.774,453.524,432.245,462.052,702.091,288.838,154.75,146.837,430.838,451.501,467.416,300.62,987.395,323.775,510.931,513.401,196.075,662.436,318.293,622.087,502.645,537.91,295.257,450.093,396.052,444.242,378.712,616.258,527.389,695.502,625.017,750.563,749.099,536.695,653.883,905.191,680.897,685.636,899.289,733.028,288.489,616.573,393.355,790.761,579.693,466.124,845.003,641.777,690.462,848.191,510.199,544.364,672.496,429.718,393.312,384.954,336.7,581.976,588.439,458.627,449.407,757.715,729.409,631.092,432.648,864.477,583.054,573.274,375.174,653.323,617.564,845.176,253.204,561.038,765.126,585.552,844.271,581.33,797.223,648.627,659.355,710.194,618.468,498.351,729.022,571.292,561.167,555.566,491.242,474.095,856.076,952.024,554.791,481.634,747.289,246.87,289.911,618.727,386.419,448.201,668.489,536.997,516.704,690.836,768.575,762.92])

# Plotting the histogram
plt.hist(data2, bins=10, density=True, alpha=0.6, color='r', label='Population 2')

# Plotting the normal distribution curve
mu, std = data2.mean(), data2.std()
xmin, xmax = data2.min(), data2.max()
x = np.linspace(xmin, xmax, 100)
p = norm.pdf(x, mu, std)
plt.plot(x, p, 'k', linewidth=2, label='Normal Distribution')

# Adding a legend
plt.legend()

# Display the plot
plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy.stats import norm

# Sample data
data1 = pd.Series([305.949,510.943,989.386,782.368,286.2,284.881,271.687,203.27,340.492,229.335,413.088,298.916,790.33,246.827,282.07,367.204,480.385,555.738,258.417,618.598,867.881,595.893,204.691,205.036,838.196,566.38,412.989,225.97,355.98,281.459])

# Plotting the histogram
plt.hist(data1, bins=10, density=True, alpha=0.6, color='b', label='Population 1')

# Plotting the normal distribution curve
mu, std = data1.mean(), data1.std()
xmin, xmax = data1.min(), data1.max()
x = np.linspace(xmin, xmax, 100)
p = norm.pdf(x, mu, std)
plt.plot(x, p, 'k', linewidth=2, label='Normal Distribution')



# Adding a legend
plt.legend()

# Display the plot
plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy.stats import norm

# Sample data
data1 = pd.Series([305.949, 510.943, 989.386, 782.368, 286.2, 284.881, 271.687, 203.27, 340.492, 229.335, 413.088, 298.916, 790.33, 246.827, 282.07, 367.204, 480.385, 555.738, 258.417, 618.598, 867.881, 595.893, 204.691, 205.036, 838.196, 566.38, 412.989, 225.97, 355.98, 281.459])
data2 = pd.Series([145.102, 364.404, 629.29, 566.42, 392.01, 728.862, 640.62, 801.732, 667.36, 605.284, 742.977, 429.783, 324.536, 969.563, 391.36, 574.774, 453.524, 432.245, 462.052, 702.091, 288.838, 154.75, 146.837, 430.838, 451.501, 467.416, 300.62, 987.395, 323.775, 510.931, 513.401, 196.075, 662.436, 318.293, 622.087, 502.645, 537.91, 295.257, 450.093, 396.052, 444.242, 378.712, 616.258, 527.389, 695.502, 625.017, 750.563, 749.099, 536.695, 653.883, 905.191, 680.897, 685.636, 899.289, 733.028, 288.489, 616.573, 393.355, 790.761, 579.693, 466.124, 845.003, 641.777, 690.462, 848.191, 510.199, 544.364, 672.496])

# Plotting the normal distribution curve for data1
mu1, std1 = data1.mean(), data1.std()
x1 = np.linspace(data1.min(), data1.max(), 100)
p1 = norm.pdf(x1, mu1, std1)
plt.plot(x1, p1, 'b', linewidth=2, label='Population 1')

# Plotting the normal distribution curve for data2
mu2, std2 = data2.mean(), data2.std()
x2 = np.linspace(data2.min(), data2.max(), 100)
p2 = norm.pdf(x2, mu2, std2)
plt.plot(x2, p2, 'r', linewidth=2, label='Population 2')

# Plotting the histograms
plt.axvline(data1.mean(), color='b', linestyle='dashed', linewidth=2)
plt.axvline(data2.mean(), color='r', linestyle='dashed', linewidth=2)
plt.hist(data1,bins=20,density=True,alpha=0.5,label='Population 1',color='b')
plt.hist(data2,bins=20,density=True,alpha=0.5,label='Population 2',color='r')

# Adding a legend
plt.legend()

# Display the plot
plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy.stats import norm  # Import the norm function

# Sample data
data1 = pd.Series([305.949, 510.943, 989.386, 782.368, 286.2, 284.881, 271.687, 203.27, 340.492, 229.335, 413.088, 298.916, 790.33, 246.827, 282.07, 367.204, 480.385, 555.738, 258.417, 618.598, 867.881, 595.893, 204.691, 205.036, 838.196, 566.38, 412.989, 225.97, 355.98, 281.459])
data2 = pd.Series([145.102,364.404,629.29,566.42,392.01,728.862,640.62,801.732,667.36,605.284,742.977,429.783,324.536,969.563,391.36,574.774,453.524,432.245,462.052,702.091,288.838,154.75,146.837,430.838,451.501,467.416,300.62,987.395,323.775,510.931,513.401,196.075,662.436,318.293,622.087,502.645,537.91,295.257,450.093,396.052,444.242,378.712,616.258,527.389,695.502,625.017,750.563,749.099,536.695,653.883,905.191,680.897,685.636,899.289,733.028,288.489,616.573,393.355,790.761,579.693,466.124,845.003,641.777,690.462,848.191,510.199,544.364,672.496,429.718,393.312,384.954,336.7,581.976,588.439,458.627,449.407,757.715,729.409,631.092,432.648,864.477,583.054,573.274,375.174,653.323,617.564,845.176,253.204,561.038,765.126,585.552,844.271,581.33,797.223,648.627,659.355,710.194,618.468,498.351,729.022,571.292,561.167,555.566,491.242,474.095,856.076,952.024,554.791,481.634,747.289,246.87,289.911,618.727,386.419,448.201,668.489,536.997,516.704,690.836,768.575,762.92])


# Plot the histograms
plt.hist(data1, bins=10, alpha=0.5, label='Population 1', color='b')
plt.hist(data2, bins=10, alpha=0.5, label='Population 2', color='r')

# Add Gaussian lines
x = np.linspace(min(data1.min(), data2.min()), max(data1.max(), data2.max()), 100)
plt.plot(x, len(data1) * np.diff(data1.value_counts().index)[1] * norm.pdf(x, data1.mean(), data1.std()), color='b')
plt.plot(x, len(data2) * np.diff(data2.value_counts().index)[1] * norm.pdf(x, data2.mean(), data2.std()), color='r')

# Adding a legend
plt.legend()

# Display the plot
plt.show()

# %%
# 19 Jan Soma  area FDs
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# Generate some random data
data = pd.Series([145.102,364.404,629.29,566.42,392.01,728.862,305.949,510.943,640.62,989.386,801.732,454.614,427.115,667.36,782.368,605.284,742.977,429.783,324.536,969.563,286.2,391.36,574.774,453.524,432.245,462.052,702.091,288.838,154.75,146.837,430.838,451.501,467.416,300.62,987.395,323.775,668.101,510.931,284.881,513.401,196.075,662.436,318.293,622.087,502.645,537.91,295.257,450.093,396.052,444.242,378.712,616.258,444.242,527.389,695.502,625.017,750.563,749.099,536.695,653.883,905.191,680.897,685.636,899.289,733.028,288.489,616.573,393.355,271.687,790.761,579.693,466.124,845.003,641.777,690.462,848.191,510.199,544.364,672.496,429.718,393.312,384.954,336.7,581.976,588.439,458.627,449.407,757.715,729.409,631.092,432.648,864.477,583.054,573.274,375.174,653.323,617.564,845.176,253.204,561.038,765.126,585.552,203.27,844.271,581.33,797.223,648.627,659.355,710.194,618.468,498.351,729.022,571.292,561.167,555.566,491.242,340.492,229.335,413.088,298.916,790.33,246.827,282.07,474.095,367.204,480.385,856.076,555.738,258.417,952.024,554.791,481.634,747.289,246.87,289.911,618.727,618.598,867.881,386.419,595.893,204.691,448.201,668.489,536.997,205.036,516.704,838.196,566.38,690.836,412.989,225.97,355.98,281.459,768.575,762.92])

# Set the bin sizes

bın_sızes = np.arange(1,60,3)

# Create the frequency distribution plots for each bin size
for bin_size in bın_sızes:
    plt.hist(data, bins=np.arange(min(data), max(data) + bin_size, bin_size))
    plt.xlabel('Value')
    plt.ylabel('Frequency')
    plt.title(f'Frequency Distribution with Bin Size {bin_size}')
    plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy.stats import norm  # Import the norm function

# Sample data
data1 = pd.Series([305.949, 510.943, 989.386, 782.368, 286.2, 284.881, 271.687, 203.27, 340.492, 229.335, 413.088, 298.916, 790.33, 246.827, 282.07, 367.204, 480.385, 555.738, 258.417, 618.598, 867.881, 595.893, 204.691, 205.036, 838.196, 566.38, 412.989, 225.97, 355.98, 281.459])
data2 = pd.Series([145.102,364.404,629.29,566.42,392.01,728.862,640.62,801.732,667.36,605.284,742.977,429.783,324.536,969.563,391.36,574.774,453.524,432.245,462.052,702.091,288.838,154.75,146.837,430.838,451.501,467.416,300.62,987.395,323.775,510.931,513.401,196.075,662.436,318.293,622.087,502.645,537.91,295.257,450.093,396.052,444.242,378.712,616.258,527.389,695.502,625.017,750.563,749.099,536.695,653.883,905.191,680.897,685.636,899.289,733.028,288.489,616.573,393.355,790.761,579.693,466.124,845.003,641.777,690.462,848.191,510.199,544.364,672.496,429.718,393.312,384.954,336.7,581.976,588.439,458.627,449.407,757.715,729.409,631.092,432.648,864.477,583.054,573.274,375.174,653.323,617.564,845.176,253.204,561.038,765.126,585.552,844.271,581.33,797.223,648.627,659.355,710.194,618.468,498.351,729.022,571.292,561.167,555.566,491.242,474.095,856.076,952.024,554.791,481.634,747.289,246.87,289.911,618.727,386.419,448.201,668.489,536.997,516.704,690.836,768.575,762.92])


# Plot the histograms
plt.hist(data1, bins=10, alpha=0.5, label='Population 1', color='b')
plt.hist(data2, bins=10, alpha=0.5, label='Population 2', color='r')

x = np.linspace(min(data1.min(), data2.min()), max(data1.max(), data2.max()), 1000)
plt.plot(x, -1 * len(data1) * np.diff(data1.value_counts().index)[1] * norm.pdf(x, data1.mean(), data1.std()), color='b')
plt.plot(x, -1 * len(data2) * np.diff(data2.value_counts().index)[1] * norm.pdf(x, data2.mean(), data2.std()), color='r')

# Adding a legend
plt.legend()

# Display the plot
plt.show()

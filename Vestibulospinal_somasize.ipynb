# %%
# 19 Jan Soma  area FDs
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from scipy.stats import norm


# Generate some random data
data = pd.Series([549.405,630.058,652.806,375.002,573.532,597.659,435.664,354.321,594.902,319.854,772.062,443.936,663.146,974.729,869.259,632.126,699.681,599.038,780.334,570.775,1187.735,885.114,733.459,755.518,162.685,838.239,226.104,750.003,565.26,311.582,700.371,311.582,135.111,1034.012,137.868,132.354,118.567,60.662,82.721,443.936,410.847,700.371,228.861,477.024,556.988,135.111,441.178,204.045,237.133,115.809,104.78,237.133,134.422,272.807,469.441,537.859,816.18,736.906,440.834,263.845,775.337,796.017,627.818,427.392,573.704,540.271,694.339,720.879,702.267,648.498,644.19,700.198,129.252,713.813,852.888,636.09,501.496,541.133,441.523,904.244,233.342,612.48,702.267,800.325,818.248,580.253,327.609,411.537,572.326,220.245,178.022,125.46,362.421,725.015,930.266,759.827,96.335,173.369,1118.629,459.446,477.197,557.332,816.353,736.044,750.52,901.486,700.543,528.38,160.444,927.509,736.389,811.01,442.385,581.459,731.047,620.063,599.555,905.278,514.593,511.664,820.833,589.904,552.507,715.019,194.05,132.354,121.324,288.662,634.711,426.185,281.596,749.142,947.5,344.154,1283.554,1162.23,1058.828,1111.218,1205.658,960.253,1047.11,1056.416,1007.128,83.238,671.418,1237.368,885.114,1021.432,737.078,643.328,657.287,583.7,519.246,739.146,739.146,910.448,173.369,174.92,183.537,939.4,979.382,1192.388,1164.987,460.135,331.918,528.208,649.532,679.346,400.335,644.362,643.672,839.79,267.12,605.586,401.024,477.197,783.953,513.559,314.857,263.673,499.083,181.986,622.648,907.69,633.505,554.403,912.86,716.226,537.169,497.704,657.632,548.716,282.63,210.249,310.893,73.76,147.519,309.514,131.664,167.51,168.889,172.335,139.247,213.006,1034.012,583.872,692.788,549.405,241.269,223.347,912.688,503.219,1094.674,160.617,484.607,272.979,437.042,679.001,741.731,308.136,778.956])

# Set the bin sizes

bın_sızes = np.arange(1,200,20)



# Create the frequency distribution plots for each bin size
for bin_size in bın_sızes:
    plt.hist(data, bins=np.arange(min(data), max(data) + bin_size, bin_size))
    plt.xlabel('Value')
    plt.ylabel('Frequency')
    plt.title(f'Frequency Distribution with Bin Size {bin_size}')
    plt.show()

# %%
# 19 Jan Soma  area FDs
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from scipy.stats import norm


# Generate some random data
data = pd.Series([549.405,630.058,652.806,375.002,573.532,597.659,435.664,354.321,594.902,319.854,772.062,443.936,663.146,974.729,869.259,632.126,699.681,599.038,780.334,570.775,1187.735,885.114,733.459,755.518,162.685,838.239,226.104,750.003,565.26,311.582,700.371,311.582,135.111,1034.012,137.868,132.354,118.567,60.662,82.721,443.936,410.847,700.371,228.861,477.024,556.988,135.111,441.178,204.045,237.133,115.809,104.78,237.133,134.422,272.807,469.441,537.859,816.18,736.906,440.834,263.845,775.337,796.017,627.818,427.392,573.704,540.271,694.339,720.879,702.267,648.498,644.19,700.198,129.252,713.813,852.888,636.09,501.496,541.133,441.523,904.244,233.342,612.48,702.267,800.325,818.248,580.253,327.609,411.537,572.326,220.245,178.022,125.46,362.421,725.015,930.266,759.827,96.335,173.369,1118.629,459.446,477.197,557.332,816.353,736.044,750.52,901.486,700.543,528.38,160.444,927.509,736.389,811.01,442.385,581.459,731.047,620.063,599.555,905.278,514.593,511.664,820.833,589.904,552.507,715.019,194.05,132.354,121.324,288.662,634.711,426.185,281.596,749.142,947.5,344.154,1283.554,1162.23,1058.828,1111.218,1205.658,960.253,1047.11,1056.416,1007.128,83.238,671.418,1237.368,885.114,1021.432,737.078,643.328,657.287,583.7,519.246,739.146,739.146,910.448,173.369,174.92,183.537,939.4,979.382,1192.388,1164.987,460.135,331.918,528.208,649.532,679.346,400.335,644.362,643.672,839.79,267.12,605.586,401.024,477.197,783.953,513.559,314.857,263.673,499.083,181.986,622.648,907.69,633.505,554.403,912.86,716.226,537.169,497.704,657.632,548.716,282.63,210.249,310.893,73.76,147.519,309.514,131.664,167.51,168.889,172.335,139.247,213.006,1034.012,583.872,692.788,549.405,241.269,223.347,912.688,503.219,1094.674,160.617,484.607,272.979,437.042,679.001,741.731,308.136,778.956])

# Set the bin sizes

bın_sızes = 5#np.arange(1,200,20)



# Create the frequency distribution plots for each bin size
plt.hist(data, bins=14, alpha=0.5)
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.title(f'Frequency Distribution with Bin Size {bin_size}')
plt.savefig('out_7mm.svg', format='svg', dpi=1200)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy.stats import norm

# Sample data
data = pd.Series([549.405,630.058,652.806,375.002,573.532,597.659,435.664,354.321,594.902,319.854,772.062,443.936,663.146,974.729,869.259,632.126,699.681,599.038,780.334,570.775,1187.735,885.114,733.459,755.518,838.239,226.104,750.003,565.26,311.582,700.371,311.582,135.111,1034.012,443.936,410.847,700.371,477.024,556.988,441.178,469.441,537.859,816.18,736.906,440.834,775.337,796.017,627.818,427.392,573.704,540.271,694.339,720.879,702.267,648.498,644.19,700.198,713.813,852.888,636.09,501.496,541.133,441.523,904.244,612.48,702.267,800.325,818.248,580.253,411.537,572.326,725.015,930.266,759.827,1118.629,459.446,477.197,557.332,816.353,736.044,750.52,901.486,700.543,528.38,927.509,736.389,811.01,442.385,581.459,731.047,620.063,599.555,905.278,514.593,511.664,820.833,589.904,552.507,715.019,634.711,426.185,281.596,749.142,947.5,344.154,1283.554,1162.23,1058.828,1111.218,1205.658,960.253,1047.11,1056.416,1007.128,671.418,1237.368,885.114,1021.432,737.078,643.328,657.287,583.7,519.246,739.146,739.146,910.448,173.369,939.4,979.382,1192.388,1164.987,460.135,331.918,528.208,649.532,679.346,400.335,644.362,643.672,839.79,605.586,401.024,477.197,783.953,513.559,499.083,181.986,622.648,907.69,633.505,554.403,912.86,716.226,537.169,497.704,657.632,548.716,310.893,309.514,1034.012,583.872,692.788,549.405,912.688,503.219,1094.674,484.607,437.042,679.001,741.731,308.136,778.956])

# Plotting the histogram
plt.hist(data, bins=8, density=True, alpha=0.6, color='b', label='Population 1')

# Plotting the normal distribution curve
mu, std = data.mean(), data.std()
xmin, xmax = data.min(), data.max()
x = np.linspace(xmin, xmax, 100)
p = norm.pdf(x, mu, std)
plt.plot(x, p, 'k', linewidth=2, label='Normal Distribution')



# Adding a legend
plt.legend()

# Display the plot
plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy.stats import norm

# Sample data
data = pd.Series([162.685,137.868,132.354,118.567,60.662,82.721,228.861,204.045,237.133,115.809,237.133,134.422,272.807,263.845,129.252,233.342,327.609,220.245,178.022,125.46,362.421,96.335,173.369,160.444,194.05,132.354,121.324,288.662,83.238,174.92,183.537,267.12,314.857,263.673,282.63,210.249,73.76,147.519,131.664,167.51,168.889,172.335,139.247,213.006,241.269,223.347,160.617])

# Plotting the histogram
plt.hist(data, bins=8, density=True, alpha=0.6, color='b', label='Population 1')

# Plotting the normal distribution curve
mu, std = data.mean(), data.std()
xmin, xmax = data.min(), data.max()
x = np.linspace(xmin, xmax, 100)
p = norm.pdf(x, mu, std)
plt.plot(x, p, 'k', linewidth=2, label='Normal Distribution')



# Adding a legend
plt.legend()

# Display the plot
plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Sample data
data1 = pd.Series([549.405,630.058,652.806,375.002,573.532,597.659,435.664,354.321,594.902,319.854,772.062,443.936,663.146,974.729,869.259,632.126,699.681,599.038,780.334,570.775,1187.735,885.114,733.459,755.518,838.239,226.104,750.003,565.26,311.582,700.371,311.582,135.111,1034.012,443.936,410.847,700.371,477.024,556.988,441.178,469.441,537.859,816.18,736.906,440.834,775.337,796.017,627.818,427.392,573.704,540.271,694.339,720.879,702.267,648.498,644.19,700.198,713.813,852.888,636.09,501.496,541.133,441.523,904.244,612.48,702.267,800.325,818.248,580.253,411.537,572.326,725.015,930.266,759.827,1118.629,459.446,477.197,557.332,816.353,736.044,750.52,901.486,700.543,528.38,927.509,736.389,811.01,442.385,581.459,731.047,620.063,599.555,905.278,514.593,511.664,820.833,589.904,552.507,715.019,634.711,426.185,281.596,749.142,947.5,344.154,1283.554,1162.23,1058.828,1111.218,1205.658,960.253,1047.11,1056.416,1007.128,671.418,1237.368,885.114,1021.432,737.078,643.328,657.287,583.7,519.246,739.146,739.146,910.448,173.369,939.4,979.382,1192.388,1164.987,460.135,331.918,528.208,649.532,679.346,400.335,644.362,643.672,839.79,605.586,401.024,477.197,783.953,513.559,499.083,181.986,622.648,907.69,633.505,554.403,912.86,716.226,537.169,497.704,657.632,548.716,310.893,309.514,1034.012,583.872,692.788,549.405,912.688,503.219,1094.674,484.607,437.042,679.001,741.731,308.136,778.956])
data2 = pd.Series([162.685,137.868,132.354,118.567,60.662,82.721,228.861,204.045,237.133,115.809,237.133,134.422,272.807,263.845,129.252,233.342,327.609,220.245,178.022,125.46,362.421,96.335,173.369,160.444,194.05,132.354,121.324,288.662,83.238,174.92,183.537,267.12,314.857,263.673,282.63,210.249,73.76,147.519,131.664,167.51,168.889,172.335,139.247,213.006,241.269,223.347,160.617])

# Plotting the histograms
plt.hist(data1, bins=13, alpha=0.5, label='Population 1', color='b')
plt.hist(data2, bins=7, alpha=0.5, label='Population 2', color='r')
plt.axvline(data1.median(), color='b', linestyle='dashed', linewidth=2)
plt.axvline(data2.median(), color='r', linestyle='dashed', linewidth=2)





# Adding a legend
plt.legend()

# Display the plot
# plt.show()
plt.savefig('out_8mm.svg', format='svg', dpi=1200)

# %%
print(np.sqrt(len(data)))
# Out:
# 14.866068747318506

# %%
# import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Sample data
data1 = pd.Series([549.405,630.058,652.806,375.002,573.532,597.659,435.664,354.321,594.902,319.854,772.062,443.936,663.146,974.729,869.259,632.126,699.681,599.038,780.334,570.775,1187.735,885.114,733.459,755.518,838.239,226.104,750.003,565.26,311.582,700.371,311.582,135.111,1034.012,443.936,410.847,700.371,477.024,556.988,441.178,469.441,537.859,816.18,736.906,440.834,775.337,796.017,627.818,427.392,573.704,540.271,694.339,720.879,702.267,648.498,644.19,700.198,713.813,852.888,636.09,501.496,541.133,441.523,904.244,612.48,702.267,800.325,818.248,580.253,411.537,572.326,725.015,930.266,759.827,1118.629,459.446,477.197,557.332,816.353,736.044,750.52,901.486,700.543,528.38,927.509,736.389,811.01,442.385,581.459,731.047,620.063,599.555,905.278,514.593,511.664,820.833,589.904,552.507,715.019,634.711,426.185,281.596,749.142,947.5,344.154,1283.554,1162.23,1058.828,1111.218,1205.658,960.253,1047.11,1056.416,1007.128,671.418,1237.368,885.114,1021.432,737.078,643.328,657.287,583.7,519.246,739.146,739.146,910.448,173.369,939.4,979.382,1192.388,1164.987,460.135,331.918,528.208,649.532,679.346,400.335,644.362,643.672,839.79,605.586,401.024,477.197,783.953,513.559,499.083,181.986,622.648,907.69,633.505,554.403,912.86,716.226,537.169,497.704,657.632,548.716,310.893,309.514,1034.012,583.872,692.788,549.405,912.688,503.219,1094.674,484.607,437.042,679.001,741.731,308.136,778.956])
data2 = pd.Series([162.685,137.868,132.354,118.567,60.662,82.721,228.861,204.045,237.133,115.809,237.133,134.422,272.807,263.845,129.252,233.342,327.609,220.245,178.022,125.46,362.421,96.335,173.369,160.444,194.05,132.354,121.324,288.662,83.238,174.92,183.537,267.12,314.857,263.673,282.63,210.249,73.76,147.519,131.664,167.51,168.889,172.335,139.247,213.006,241.269,223.347,160.617])

# Plotting the histograms with different bin sizes
plt.figure(figsize=(10, 5))  # Create a new figure
plt.subplot(1, 2, 1)  # Create subplots for the histograms
plt.hist(data1, bins=12, alpha=0.5, label='Population 1', color='b')  # Plot the first histogram with 12 bins
plt.legend()  # Add legend
plt.subplot(1, 2, 2)  # Move to the second subplot
plt.hist(data2, bins=8, alpha=0.5, label='Population 2', color='r')  # Plot the second histogram with 8 bins
plt.legend()  # Add legend

# Display the plot
plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy.stats import norm  # Import the norm function

# Sample data
data1 = pd.Series([549.405,630.058,652.806,375.002,573.532,597.659,435.664,354.321,594.902,319.854,772.062,443.936,663.146,974.729,869.259,632.126,699.681,599.038,780.334,570.775,1187.735,885.114,733.459,755.518,838.239,226.104,750.003,565.26,311.582,700.371,311.582,135.111,1034.012,443.936,410.847,700.371,477.024,556.988,441.178,469.441,537.859,816.18,736.906,440.834,775.337,796.017,627.818,427.392,573.704,540.271,694.339,720.879,702.267,648.498,644.19,700.198,713.813,852.888,636.09,501.496,541.133,441.523,904.244,612.48,702.267,800.325,818.248,580.253,411.537,572.326,725.015,930.266,759.827,1118.629,459.446,477.197,557.332,816.353,736.044,750.52,901.486,700.543,528.38,927.509,736.389,811.01,442.385,581.459,731.047,620.063,599.555,905.278,514.593,511.664,820.833,589.904,552.507,715.019,634.711,426.185,281.596,749.142,947.5,344.154,1283.554,1162.23,1058.828,1111.218,1205.658,960.253,1047.11,1056.416,1007.128,671.418,1237.368,885.114,1021.432,737.078,643.328,657.287,583.7,519.246,739.146,739.146,910.448,173.369,939.4,979.382,1192.388,1164.987,460.135,331.918,528.208,649.532,679.346,400.335,644.362,643.672,839.79,605.586,401.024,477.197,783.953,513.559,499.083,181.986,622.648,907.69,633.505,554.403,912.86,716.226,537.169,497.704,657.632,548.716,310.893,309.514,1034.012,583.872,692.788,549.405,912.688,503.219,1094.674,484.607,437.042,679.001,741.731,308.136,778.956])
data2 = pd.Series([162.685,137.868,132.354,118.567,60.662,82.721,228.861,204.045,237.133,115.809,237.133,134.422,272.807,263.845,129.252,233.342,327.609,220.245,178.022,125.46,362.421,96.335,173.369,160.444,194.05,132.354,121.324,288.662,83.238,174.92,183.537,267.12,314.857,263.673,282.63,210.249,73.76,147.519,131.664,167.51,168.889,172.335,139.247,213.006,241.269,223.347,160.617])


# Plot the histograms
plt.hist(data1, bins=10, alpha=0.5, label='Population 1', color='b')
plt.hist(data2, bins=10, alpha=0.5, label='Population 2', color='r')

x = np.linspace(min(data1.min(), data2.min()), max(data1.max(), data2.max()), 1000)
plt.plot(x, -1 * len(data1) * np.diff(data1.value_counts().index)[0] * norm.pdf(x, data1.mean(), data1.std()), color='b')
plt.plot(x, -1 * len(data2) * np.diff(data2.value_counts().index)[1] * norm.pdf(x, data2.mean(), data2.std()), color='r')

# Adding a legend
plt.legend()

# Display the plot
plt.show()
